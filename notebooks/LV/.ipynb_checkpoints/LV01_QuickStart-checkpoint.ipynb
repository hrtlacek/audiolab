# %% [markdown]
# # Lesson 1: Quickstart

# %% [markdown]
# ## Loading some Libraries to use for the rest of this

# %%
import IPython
import librosa
import soundfile as sf
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## File Loading, Display, Audition, Writing

# %%
p = '../data/drumLoop.wav'

# %%
IPython.display.Audio(p)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
x,sr = librosa.load(p,sr=44100)
plot(x)

# %%
mag = magnitude_spectrum(x,Fs=sr)

# %%
S = specgram(x, Fs=sr)

# %%
outPutPath = '/tmp/tempFile.wav'
# librosa.output.write_wav(outPutPath, x,sr) deprecated!
sf.write(outPutPath, x, sr, subtype='PCM_24')
