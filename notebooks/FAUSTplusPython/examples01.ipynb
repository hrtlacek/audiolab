# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import FAUSTPy

# %%
dspFile = 'testSynth.dsp'

# %%
cat {dspFile}
# Out:
# import("stdfaust.lib");
# f = hslider("freq",100,10,1200,0.1);
# o = os.osc(f);
# process = o;

# %%
sr = 44100 #Hz
T = 0.1 #seconds
N = int(T*sr) #samps
n = np.arange(N)
t = n/sr

# %%
mySynth = FAUSTPy.FAUST(dspFile,sr)

# %%
audio = mySynth.compute(N)

# %%
audio.shape
# Out:
# (1, 4410)

# %%
plot(audio[0,:])
title("Audio Output")
show()
